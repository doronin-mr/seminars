# %%
print(*(lambda a: list((a[min(i+1, len(a)-1)] if i % 2 == 0 else a[i-1]) for i in range(len(a))))(input().split()))

# %%
a = input().split()
for i in range(len(a)):
    print(a[min(i+1, len(a)-1) if i % 2 == 0 else i-1], end=" ")

# %%
a = input().split()
a[:-1:2], a[1::2] = a[1::2], a[:-1:2]
print(*a)
