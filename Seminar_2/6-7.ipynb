# %%
a = input().split()
for i in a:
    if a.count(i) == 1:
        print(i, end=" ")

# %%
a = input().split()
r = 0
m = 0
for i in a:
    if a.count(i) > m:
        r = i
        m = a.count(i)
print(r)
