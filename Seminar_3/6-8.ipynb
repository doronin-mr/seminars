# %%
import numpy as np

def mnk(x, y):
    x = np.array(x)
    y = np.array(y)
    k = (np.mean(x*y) - np.mean(x)*np.mean(y)) \
        /(np.mean(x**2)-np.mean(x)**2)
    return k, b

print(mnk([1, 2, 3], [2, 3, 4.5]))

# %%
np.polyfit([1, 2, 3], [2, 3, 4.5], 1)

# %%
rng = np.random.default_rng(seed=67)
N = int(input())
x = rng.wald(1, 101, N)
y = rng.rayleigh(5, N)

# %%
k, b = mnk(x, y)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))

plt.plot(x, y, linestyle="none", marker="d")

plt.plot(x, k*x + b)

plt.show()
